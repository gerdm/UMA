# %%
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
s = np.array([10, 40, 80, 140, 200, 300])
y = np.array([3.1, 11.9, 21, 29.9, 37.3, 42.7])

# %%
a, b = 40, 5e-3

# %%
gi = lambda a, b, s, y: a * (1 - np.exp(-b * s)) - y
g = np.array([[gi(a, b, si, yi) for (si, yi) in zip(s, y)]]).T

# %%
plt.scatter(s, y);
# First Guess
plt.plot(s, a * (1 - np.exp(-b*s)))
# After First Iteration
plt.plot(s,  4.60813365e+01 * (1 - np.exp(-7.61743682e-03*s)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Jg_0 = 1 - np.exp(-s * b)
Jg_1 = s * a * np.exp(-s*b)
Jg = np.array([Jg_0, Jg_1]).T
Jg
# Out:
# array([[  4.87705755e-02,   3.80491770e+02],
#        [  1.81269247e-01,   1.30996920e+03],
#        [  3.29679954e-01,   2.14502415e+03],
#        [  5.03414696e-01,   2.78087770e+03],
#        [  6.32120559e-01,   2.94303553e+03],
#        [  7.76869840e-01,   2.67756192e+03]])

# %%
np.array([[40, 0.005]]).T - np.dot(inv(np.dot(Jg.T, Jg)), np.dot(Jg.T, g))
# Out:
# array([[  4.60813365e+01],
#        [  7.61743682e-03]])
